# %% [markdown]
# # Occasions Annotations

# %% [markdown]
# ## Bin of 3-5 `guest_count`
# Let's look at a few tables (taken from `best_bars_35.csv`, version of August 27th), to get an idea of the different occasions.

# %% [markdown]
# Our initial set of **occasions** for the 3-5 bin is:
# 1. `Business Date`
# 2. `Dinner Date`
# 3. `Social Gathering`
# 4. `Family Event`
# 5. `Party`
# 6. `Drinking`
# 7. `After Work`

# %% [markdown]
# ----------

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
bars = pd.read_csv("../feature_engineering/best_bars_35.csv")

# %%
bars.head()
# Out:
#    bar_id  guest_count_count  guest_count_mean  guest_count_std  \
# 0   19531             1092.0          1.470696         1.191961
# 1    3539             1251.0          1.439648         0.775729
# 2   12392              829.0          1.874548         1.459168
# 3    1150              571.0          1.367776         0.678966
# 4   19146              338.0          1.476331         0.868695
#
#    guest_count_min  guest_count_25%  guest_count_50%  guest_count_75%  \
# 0              1.0              1.0              1.0              2.0
# 1              1.0              1.0              1.0              2.0
# 2              1.0              1.0              1.0              2.0
# 3              1.0              1.0              1.0              2.0
# 4              1.0              1.0              1.0              2.0
#
#    guest_count_max
# 0             16.0
# 1             13.0
# 2             13.0
# 3              5.0
# 4              6.0

# %%
print("The table best_bars_35.csv contains of {} different bars.".format(len(bars)))
# Out:
# The table best_bars_35.csv contains of 35 different bars.

# %%
df = pd.read_csv('../data/original_data.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1754466 entries, 0 to 1754465
# Data columns (total 26 columns):
# city                           object
# bar_id                         int64
# order_id                       int64
# order_time                     object
# order_item_id                  int64
# title                          object
# category_id                    float64
# beer_brand_id                  int64
# beer_serving_type_id           int64
# beer_volume                    float64
# item_qty                       float64
# sales_before_tax               float64
# sales_inc_tax                  float64
# guest_count                    int64
# waiter_id                      float64
# country                        object
# country_id                     int64
# state                          object
# state_id                       int64
# timezone                       object
# bar_type_id                    int64
# status                         int64
# last_status                    int64
# is_bulk                        int64
# bar_type                       object
# data_availability_status_id    int64
# dtypes: float64(6), int64(13), object(7)
# memory usage: 348.0+ MB

# %%
features = ['city', 'bar_id', 'order_id', 'order_time', 'title', 'category_id', 'beer_brand_id',
            'beer_serving_type_id', 'beer_volume', 'item_qty', 'sales_before_tax', 'guest_count', 'bar_type']
df = df[features]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1754466 entries, 0 to 1754465
# Data columns (total 13 columns):
# city                    object
# bar_id                  int64
# order_id                int64
# order_time              object
# title                   object
# category_id             float64
# beer_brand_id           int64
# beer_serving_type_id    int64
# beer_volume             float64
# item_qty                float64
# sales_before_tax        float64
# guest_count             int64
# bar_type                object
# dtypes: float64(4), int64(5), object(4)
# memory usage: 174.0+ MB

# %%
orig_len = len(df)
print("Original dataframe contains {} entries.".format(orig_len))
# Out:
# Original dataframe contains 1754466 entries.

# %% [markdown]
# Keep orders by the best 35 bars only:

# %%
df = df[df['bar_id'].isin(list(bars.bar_id))]

# %%
cur_len = len(df)
print("When filtering for the 35 best bars, we are left with {0} entries which are {1:.2f}% of the original data."
      .format(cur_len, 100 * float(cur_len) / orig_len))
# Out:
# When filtering for the 35 best bars, we are left with 136727 entries which are 7.79% of the original data.

# %% [markdown]
# Create (degenerated) tables:

# %%
tables = df.drop_duplicates(subset='order_id', keep='first')
tables.set_index('order_id', inplace=True)
tables = tables[['guest_count']]
print("We have {} tables.".format(len(tables)))

tables.head()
# Out:
# We have 31790 tables.
#            guest_count
# order_id
# 650469872            2
# 650470006            1
# 650470224            1
# 650469902            1
# 649877875            1

# %% [markdown]
# -----

# %% [markdown]
# ### The Annotations
#
# Pick 20 tables of 3 to 5 guests

# %%
COUNT = 20

# %%
tables_3to5 = tables[(tables['guest_count'] >= 3) & (tables['guest_count'] <= 5)]
print("We have {} tables of 3 to 5 guests".format(len(tables_3to5)))
# Out:
# We have 3133 tables of 3 to 5 guests

# %%
import random

# %%
picked_tables = random.sample(list(tables_3to5.index), COUNT)

# %%
print("Got {} tables".format(len(picked_tables)))
# Out:
# Got 20 tables

# %%
picked_tables
# Out:
# [652039598,
#  647593545,
#  647589141,
#  649192816,
#  648530202,
#  649417245,
#  647559306,
#  647970599,
#  649887670,
#  650361187,
#  649418218,
#  651764317,
#  651118903,
#  648235994,
#  648771114,
#  648758501,
#  651638259,
#  651796784,
#  650348899,
#  652040252]

# %% [markdown]
# ----

# %% [markdown]
# ### 1. Table 648322489

# %%
df[df['order_id'] == 651992091]
# Out:
#              city  bar_id   order_id               order_time  \
# 393092  Vancouver   11290  651992091  2019-07-20 20:54:00.000
# 393093  Vancouver   11290  651992091  2019-07-20 20:54:00.000
# 393094  Vancouver   11290  651992091  2019-07-20 20:54:00.000
# 393095  Vancouver   11290  651992091  2019-07-20 20:54:00.000
# 393096  Vancouver   11290  651992091  2019-07-20 20:54:00.000
#
#                    title  category_id  beer_brand_id  beer_serving_type_id  \
# 393092   PINT WOBBLY POP          1.0           2374                     2
# 393093    JUG STEAMWORKS          1.0           2524                     2
# 393094  **FIRST DRINKS**          5.0              0                     0
# 393095     QUESO CHS DIP          2.0              0                     0
# 393096       SHARK BITES          2.0              0                     0
#
#         beer_volume  item_qty  sales_before_tax  guest_count bar_type
# 393092         0.59       1.0              8.00            3  Bar/Pub
# 393093         1.77       1.0             21.00            3  Bar/Pub
# 393094         0.00       1.0              0.00            3  Bar/Pub
# 393095         0.00       1.0             13.75            3  Bar/Pub
# 393096         0.00       1.0             14.00            3  Bar/Pub

# %% [markdown]
# July 20th (Saturday), 20:54, 3 guests at a Bar/Pub.
#
# - 2 Dishes:
#   - Shark Bites
#   - Mexican Cheese Dip
# - 2 Drinks:
#   - Wobbly Pop PINT
#   - Steamworks JUG
# - Couple of drinks
#
# `Social Gathering`

# %% [markdown]
# ### 2. Table 647593370

# %%
df[df['order_id'] == 647593370]
# Out:
#                   city  bar_id   order_id               order_time  \
# 1192611  Saint-Georges    1544  647593370  2019-07-14 18:20:51.000
# 1192612  Saint-Georges    1544  647593370  2019-07-14 18:20:51.000
# 1192613  Saint-Georges    1544  647593370  2019-07-14 18:20:51.000
# 1192614  Saint-Georges    1544  647593370  2019-07-14 18:20:51.000
# 1192615  Saint-Georges    1544  647593370  2019-07-14 18:20:51.000
# 1192616  Saint-Georges    1544  647593370  2019-07-14 18:20:51.000
# 1192617  Saint-Georges    1544  647593370  2019-07-14 18:20:51.000
# 1192618  Saint-Georges    1544  647593370  2019-07-14 18:20:51.000
#
#                       title  category_id  beer_brand_id  beer_serving_type_id  \
# 1192611        Pizza Enfant          2.0              0                     0
# 1192612    T.H GAT. FROMAGE          2.0              0                     0
# 1192613     BUD LIGHT PINTE          1.0             15                     2
# 1192614  T.H CREVETTES (25)          2.0              0                     0
# 1192615   T.H GAT. CAROTTES          2.0              0                     0
# 1192616         GLACEE ENF.          2.0              0                     0
# 1192617          T.H SAUMON          2.0              0                     0
# 1192618             CAFE TH          4.0              0                     0
#
#          beer_volume  item_qty  sales_before_tax  guest_count       bar_type
# 1192611        0.000       1.0              6.25            3  Casual Dining
# 1192612        0.000       1.0              0.00            3  Casual Dining
# 1192613        0.591       1.0              6.15            3  Casual Dining
# 1192614        0.000       1.0             28.35            3  Casual Dining
# 1192615        0.000       1.0              0.00            3  Casual Dining
# 1192616        0.000       1.0              0.00            3  Casual Dining
# 1192617        0.000       1.0             27.30            3  Casual Dining
# 1192618        0.000       2.0              0.00            3  Casual Dining

# %% [markdown]
# July 14th (Sunday), 18:20, 3 guests at a Casual Dining.
#
# - 5 Dishes:
#   - Pizza for a kid (Pizza Enfant)
#   - Cheese Cake (no cost) (Gateau au Fromage)
#   - Carrot Cake (no cost) (Gateau au Carottes)
#   - 25 Shrimps (Crevettes)
#   - Salmon Fish (Saumon)
# - 2 Drinks:
#   - Bud Light PINT
#   - Coffee
#
# Probably 2 adults with their child.
# `Family Event`

# %% [markdown]
# ### 3. Table 648549826

# %%
df[df['order_id'] == 648549826]
# Out:
#             city  bar_id   order_id               order_time          title  \
# 804824  Saguenay    3474  648549826  2019-07-16 12:09:38.000  PEPSI CANETTE
# 804825  Saguenay    3474  648549826  2019-07-16 12:09:38.000  CÔTE DE BOEUF
#
#         category_id  beer_brand_id  beer_serving_type_id  beer_volume  \
# 804824          4.0              0                     0          0.0
# 804825          2.0              0                     0          0.0
#
#         item_qty  sales_before_tax  guest_count bar_type
# 804824       2.0              5.22            3  Bar/Pub
# 804825       2.0             30.00            3  Bar/Pub

# %% [markdown]
# July 16th (Tuesday), 12:10, 3 guests at a Bar/Pub.
#
# - 1 Main Dish:
#   - Beef (Cote de Boeuf)
# - 1 Drink:
#   - Pepsi Can (Pepsi Canette)
#
# Looks like a 1 person meal to me, but ...
# A **new** occasion: `Lunch`

# %% [markdown]
# ### 4. Table 651914298

# %%
df[df['order_id'] == 651914298]
# Out:
#                  city  bar_id   order_id               order_time  \
# 174822  Saint-Romuald    1150  651914298  2019-07-20 20:06:00.000
# 174823  Saint-Romuald    1150  651914298  2019-07-20 20:06:00.000
# 174824  Saint-Romuald    1150  651914298  2019-07-20 20:06:00.000
# 174825  Saint-Romuald    1150  651914298  2019-07-20 20:06:00.000
#
#                       title  category_id  beer_brand_id  beer_serving_type_id  \
# 174822  PT.RONDELLES OIGNON          2.0              0                     0
# 174823      FINE JARDINIERE          2.0              0                     0
# 174824       MINI HAWAIENNE          2.0              0                     0
# 174825    FINE ITAL. EPICEE          2.0              0                     0
#
#         beer_volume  item_qty  sales_before_tax  guest_count       bar_type
# 174822          0.0       1.0              5.95            3  Casual Dining
# 174823          0.0       1.0             14.45            3  Casual Dining
# 174824          0.0       1.0              9.95            3  Casual Dining
# 174825          0.0       1.0             15.45            3  Casual Dining

# %% [markdown]
# July 20th (Sunday), 20:06, 3 guests at a Casual Dining.
#
# - 4 Dishes:
#   - Onion Rings (Rondelles Oignon)
#   - Vegetables Plate (Fine Jardiniere)
#   - Mini Pizza (well ... I think ... Mini Hawaienne)
#   - Some (probably ham of some kind) Spicy Italian dish (Fine Italian Epicee)
#
# `Socail Gathering`

# %% [markdown]
# ### 5. Table 649180460

# %%
df[df['order_id'] == 649180460]
# Out:
#               city  bar_id   order_id               order_time  \
# 1429566  Longueuil    1532  649180460  2019-07-17 13:00:27.000
# 1429567  Longueuil    1532  649180460  2019-07-17 13:00:27.000
#
#                    title  category_id  beer_brand_id  beer_serving_type_id  \
# 1429566  PAD THAI POULET          2.0              0                     0
# 1429567    PAD THAI VEGE          2.0              0                     0
#
#          beer_volume  item_qty  sales_before_tax  guest_count  \
# 1429566          0.0       2.0             29.90            3
# 1429567          0.0       1.0             13.95            3
#
#                   bar_type
# 1429566  Trendy Restaurant
# 1429567  Trendy Restaurant

# %% [markdown]
# July 17th (Wednesday), 13:00, 3 guests at a Trendy Restaurant.
#
# - 2 Dishes:
#   - Chicken Pad Thai
#   - Veggie Pad Thai
#
# Looks like a casual `Lunch` to me.

# %% [markdown]
# ### 6. Table 650168254

# %%
df[df['order_id'] == 650168254]
# Out:
#              city  bar_id   order_id               order_time  \
# 1337157  Gatineau    3539  650168254  2019-07-18 16:32:26.000
# 1337158  Gatineau    3539  650168254  2019-07-18 16:32:26.000
# 1337159  Gatineau    3539  650168254  2019-07-18 16:32:26.000
# 1337160  Gatineau    3539  650168254  2019-07-18 16:32:26.000
# 1337161  Gatineau    3539  650168254  2019-07-18 16:32:26.000
# 1337162  Gatineau    3539  650168254  2019-07-18 16:32:26.000
# 1337163  Gatineau    3539  650168254  2019-07-18 16:32:26.000
# 1337164  Gatineau    3539  650168254  2019-07-18 16:32:26.000
# 1337165  Gatineau    3539  650168254  2019-07-18 16:32:26.000
# 1337166  Gatineau    3539  650168254  2019-07-18 16:32:26.000
# 1337167  Gatineau    3539  650168254  2019-07-18 16:32:26.000
# 1337168  Gatineau    3539  650168254  2019-07-18 16:32:26.000
# 1337169  Gatineau    3539  650168254  2019-07-18 16:32:26.000
#
#                             title  category_id  beer_brand_id  \
# 1337157  REMPLACE PAR SAL JARDINI          5.0              0
# 1337158          CROQUETTE ENFANT          2.0              0
# 1337159                   MESSAGE          5.0              0
# 1337160                BUCK BUGER          3.0              0
# 1337161                     PEPSI          4.0              0
# 1337162                CONDIMENTS          2.0              0
# 1337163                   MESSAGE          5.0              0
# 1337164                 COKE DIET          4.0              0
# 1337165           S-MARIN COMBINE          2.0              0
# 1337166                   MESSAGE          5.0              0
# 1337167                CONDIMENTS          2.0              0
# 1337168         MINI PIZZA ENFANT          2.0              0
# 1337169                 PEPPERONI          2.0              0
#
#          beer_serving_type_id  beer_volume  item_qty  sales_before_tax  \
# 1337157                     0          0.0       1.0              2.50
# 1337158                     0          0.0       1.0              6.95
# 1337159                     0          0.0       1.0              0.00
# 1337160                     0          0.0       1.0             14.00
# 1337161                     0          0.0       1.0              2.75
# 1337162                     0          0.0       1.0              0.00
# 1337163                     0          0.0       1.0              0.00
# 1337164                     0          0.0       1.0              2.75
# 1337165                     0          0.0       1.0             14.00
# 1337166                     0          0.0       1.0              0.00
# 1337167                     0          0.0       1.0              0.00
# 1337168                     0          0.0       1.0              6.95
# 1337169                     0          0.0       1.0              0.00
#
#          guest_count bar_type
# 1337157            4      NaN
# 1337158            4      NaN
# 1337159            4      NaN
# 1337160            4      NaN
# 1337161            4      NaN
# 1337162            4      NaN
# 1337163            4      NaN
# 1337164            4      NaN
# 1337165            4      NaN
# 1337166            4      NaN
# 1337167            4      NaN
# 1337168            4      NaN
# 1337169            4      NaN

# %% [markdown]
# July 18th (Thursday), 16:32, 4 guests.
#
# - 3 Dishes:
#   - Croquette for a kid
#   - Mini Pizza (w/ Pepperoni) for a kid
#   - Marine combine dish (S-marin Combine)
# - Sides:
#   - Sauces (probably for the croquette)
#   - Jardini Fish (Arowana)
# - Drinks:
#   - Coke Diet
#   - Pepsi
#   - Buck cocktail (Buck Buger)
#
# `Family Event`
# Looks like we're gonna tag every table with a kid as Family Event occasion

# %% [markdown]
# ### 7. Table 647963198

# %%
df[df['order_id'] == 647963198]
# Out:
#             city  bar_id   order_id               order_time          title  \
# 240203  Gatineau   17624  647963198  2019-07-15 12:47:28.000  JUMBO PLATTER
#
#         category_id  beer_brand_id  beer_serving_type_id  beer_volume  \
# 240203          2.0              0                     0          0.0
#
#         item_qty  sales_before_tax  guest_count bar_type
# 240203       1.0             16.98            4  Bar/Pub

# %% [markdown]
# July 15th (Monday), 12:47, 4 guests at a Bar/Pub.
#
# - 1 Jumbo Platter Dish
#
# `Lunch`

# %% [markdown]
# ### 8. Table 650984036

# %%
df[df['order_id'] == 650984036]
# Out:
#                   city  bar_id   order_id               order_time  \
# 280435  Trois-Rivières    2068  650984036  2019-07-19 18:09:52.000
# 280436  Trois-Rivières    2068  650984036  2019-07-19 18:09:52.000
# 280437  Trois-Rivières    2068  650984036  2019-07-19 18:09:52.000
# 280438  Trois-Rivières    2068  650984036  2019-07-19 18:09:52.000
# 280439  Trois-Rivières    2068  650984036  2019-07-19 18:09:52.000
# 280440  Trois-Rivières    2068  650984036  2019-07-19 18:09:52.000
# 280441  Trois-Rivières    2068  650984036  2019-07-19 18:09:52.000
# 280442  Trois-Rivières    2068  650984036  2019-07-19 18:09:52.000
# 280443  Trois-Rivières    2068  650984036  2019-07-19 18:09:52.000
# 280444  Trois-Rivières    2068  650984036  2019-07-19 18:09:52.000
# 280445  Trois-Rivières    2068  650984036  2019-07-19 18:09:52.000
#
#                      title  category_id  beer_brand_id  beer_serving_type_id  \
# 280435   Ent. Salade César          2.0              0                     0
# 280436       Calmars Frits          2.0              0                     0
# 280437    Bâtonnet Fromage          2.0              0                     0
# 280438       V. Sangria BL          6.0              0                     0
# 280439  Filet Mignon Mondo          2.0              0                     0
# 280440    Mignon Crevettes          2.0              0                     0
# 280441     Enf. Mini Pizza          2.0              0                     0
# 280442         RHUM SPICED          3.0              0                     0
# 280443  J'ENLEVE SERV. # 2          5.0              0                     0
# 280444     Esc. Parmigiana          2.0              0                     0
# 280445    Enf. Mini Burger          2.0              0                     0
#
#         beer_volume  item_qty  sales_before_tax  guest_count       bar_type
# 280435          0.0       1.0              8.99            5  Casual Dining
# 280436          0.0       1.0             11.99            5  Casual Dining
# 280437          0.0       1.0              7.99            5  Casual Dining
# 280438          0.0       1.0              6.09            5  Casual Dining
# 280439          0.0       1.0             33.99            5  Casual Dining
# 280440          0.0       1.0             39.94            5  Casual Dining
# 280441          0.0       1.0              7.99            5  Casual Dining
# 280442          0.0       1.0              6.10            5  Casual Dining
# 280443          0.0       1.0              0.00            5  Casual Dining
# 280444          0.0       2.0             46.23            5  Casual Dining
# 280445          0.0       1.0              8.99            5  Casual Dining

# %% [markdown]
# July 19th (Friday), 18:10, 5 guests at a Casual Dining.
#
# - 9 Dishes:
#   - 1 Salad
#   - 1 Fried Squids (Calmars Frits)
#   - 1 Cheese Stick (Batonnet Fromage)
#   - 1 Filet Mignon
#   - 1 Mignon Shrimp (Mignon Crevettes)
#   - 1 Mini Pizza
#   - 2 Parmigiana Meat (Escalopes Parmigiana)
#   - 1 Mini Burger
# - 1 Wine:
#   - Sangria Bottle
# - 1 Alcoholic Drink:
#   - Rum (Rhum Spiced)
#
# `Dinner`

# %% [markdown]
# ### 9. Table 648549853

# %%
df[df['order_id'] == 648549853]
# Out:
#           city  bar_id   order_id               order_time  \
# 756523  Québec   12764  648549853  2019-07-16 13:39:04.000
# 756524  Québec   12764  648549853  2019-07-16 13:39:04.000
# 756525  Québec   12764  648549853  2019-07-16 13:39:04.000
# 756526  Québec   12764  648549853  2019-07-16 13:39:04.000
# 756527  Québec   12764  648549853  2019-07-16 13:39:04.000
#
#                        title  category_id  beer_brand_id  \
# 756523  CAFÉ ALLONGÉ / COURT          4.0              0
# 756524       DOUBLE ESPRESSO          4.0              0
# 756525          CAFE AU LAIT          4.0              0
# 756526              ASS. MER          3.0              0
# 756527          DESSERT MIDI          2.0              0
#
#         beer_serving_type_id  beer_volume  item_qty  sales_before_tax  \
# 756523                     0          0.0       2.0               7.0
# 756524                     0          0.0       1.0               5.0
# 756525                     0          0.0       1.0               4.5
# 756526                     0          0.0       4.0              72.0
# 756527                     0          0.0       1.0               6.0
#
#         guest_count bar_type
# 756523            4  Bar/Pub
# 756524            4  Bar/Pub
# 756525            4  Bar/Pub
# 756526            4  Bar/Pub
# 756527            4  Bar/Pub

# %% [markdown]
# July 16th (Tuesday), 13:40, 4 guests at a Bar/Pub.
#
# - 1 Dessert
# - 4 Alcoholic Drink, Cocktails
# - 4 Coffee cups
#
# `Social Gathering`

# %% [markdown]
# ### 10. Table 650796472

# %%
df[df['order_id'] == 650796472]
# Out:
#               city  bar_id   order_id               order_time          title  \
# 805877  Sherbrooke    2853  650796472  2019-07-19 12:27:49.000     RHUM EPICE
# 805878  Sherbrooke    2853  650796472  2019-07-19 12:27:49.000       BUD 20oz
# 805879  Sherbrooke    2853  650796472  2019-07-19 12:27:49.000  BLOODY CEASAR
#
#         category_id  beer_brand_id  beer_serving_type_id  beer_volume  \
# 805877          3.0              0                     0        0.000
# 805878          1.0             71                     2        2.364
# 805879          3.0              0                     0        0.000
#
#         item_qty  sales_before_tax  guest_count bar_type
# 805877       2.0             10.86            4  Bar/Pub
# 805878       4.0             29.56            4  Bar/Pub
# 805879       1.0              6.99            4  Bar/Pub

# %% [markdown]
# July 19th (Friday), 12:30, 4 guests at a Bar/Pub.
#
# - 1 Beer (BUD)
# - 2 Alcoholic Drinks (Rum & Bloody Caesar)
#
# `Drinking`

# %% [markdown]
# ### 11. Table 651964557

# %%
df[df['order_id'] == 651964557]
# Out:
#                    city  bar_id   order_id               order_time  \
# 1010387  Trois-Rivières    2068  651964557  2019-07-20 19:09:08.000
# 1010388  Trois-Rivières    2068  651964557  2019-07-20 19:09:08.000
# 1010389  Trois-Rivières    2068  651964557  2019-07-20 19:09:08.000
# 1010390  Trois-Rivières    2068  651964557  2019-07-20 19:09:08.000
# 1010391  Trois-Rivières    2068  651964557  2019-07-20 19:09:08.000
# 1010392  Trois-Rivières    2068  651964557  2019-07-20 19:09:08.000
# 1010393  Trois-Rivières    2068  651964557  2019-07-20 19:09:08.000
# 1010394  Trois-Rivières    2068  651964557  2019-07-20 19:09:08.000
# 1010395  Trois-Rivières    2068  651964557  2019-07-20 19:09:08.000
# 1010396  Trois-Rivières    2068  651964557  2019-07-20 19:09:08.000
# 1010397  Trois-Rivières    2068  651964557  2019-07-20 19:09:08.000
#
#                       title  category_id  beer_brand_id  beer_serving_type_id  \
# 1010387      GR. Bruschetta          2.0              0                     0
# 1010388     GR. General Tao          2.0              0                     0
# 1010389            Can  7UP          4.0              0                     0
# 1010390       V. Sangria BL          6.0              0                     0
# 1010391      GR. Végé Mondo          NaN              0                     0
# 1010392         Potage Inc.          2.0              0                     0
# 1010393          SALADE INC          2.0              0                     0
# 1010394  GR. Fett. Romanoff          2.0              0                     0
# 1010395  J'ENLEVE SERV. # 2          5.0              0                     0
# 1010396  V. Blanc Selection          6.0              0                     0
# 1010397      Shock Top 20oz          1.0            267                     2
#
#          beer_volume  item_qty  sales_before_tax  guest_count       bar_type
# 1010387        0.000       1.0              5.99            3  Casual Dining
# 1010388        0.000       1.0             22.99            3  Casual Dining
# 1010389        0.000       1.0              3.04            3  Casual Dining
# 1010390        0.000       1.0              6.09            3  Casual Dining
# 1010391        0.000       1.0             19.99            3  Casual Dining
# 1010392        0.000       1.0              0.00            3  Casual Dining
# 1010393        0.000       2.0              0.00            3  Casual Dining
# 1010394        0.000       1.0             22.99            3  Casual Dining
# 1010395        0.000       1.0              0.00            3  Casual Dining
# 1010396        0.000       1.0              7.61            3  Casual Dining
# 1010397        0.591       1.0              7.39            3  Casual Dining

# %% [markdown]
# July 20th (Saturday), 19:10, 3 guests at a Casual Dining.
#
# - 5 Dishes:
#   - 1 Bruscetta
#   - 1 Fried Chicken (General Tao)
#   - 1 Veggie Plate (Vege Mondo)
#   - 1 Soup (Potage)
#   - 1 Strawberries Dessert (Fett. Romanoff)
# - 1 Soft Drinks:
#   - 1 7UP Can
# - 1 Wine:
#   - 1 Sangria Bottle
#   - 1 Blanc Wine (Blanc Selection)
#
# `Dinner`

# %% [markdown]
# ### 12. Table 651250493

# %%
df[df['order_id'] == 651250493]
# Out:
#                  city  bar_id   order_id               order_time  \
# 542540  Saint-Georges   19531  651250493  2019-07-19 19:58:43.000
# 542541  Saint-Georges   19531  651250493  2019-07-19 19:58:43.000
# 542542  Saint-Georges   19531  651250493  2019-07-19 19:58:43.000
# 542543  Saint-Georges   19531  651250493  2019-07-19 19:58:43.000
# 542544  Saint-Georges   19531  651250493  2019-07-19 19:58:43.000
#
#                    title  category_id  beer_brand_id  beer_serving_type_id  \
# 542540        BURGER BLT          2.0              0                     0
# 542541         FORESTIER          3.0              0                     0
# 542542    COMPTE DRACULA          3.0              0                     0
# 542543       GENERAL TAO          2.0              0                     0
# 542544  BURGER TI-CROTTE          2.0              0                     0
#
#         beer_volume  item_qty  sales_before_tax  guest_count bar_type
# 542540          0.0       1.0             16.99            4  Bar/Pub
# 542541          0.0       1.0              9.99            4  Bar/Pub
# 542542          0.0       1.0              8.99            4  Bar/Pub
# 542543          0.0       1.0             19.99            4  Bar/Pub
# 542544          0.0       1.0             17.99            4  Bar/Pub

# %% [markdown]
# July 19th (Friday), 20:00, 4 guests at a Bar/Pub.
#
# - 3 Main Dishes:
#   - 2 Burgers
#   - 1 Fried Chicken (General Tao)
# - 2 Cocktails:
#   - 1 Forestier
#   - 1 Compte Dracula
#
# `Social Gathering`

# %% [markdown]
# ### 13. Table 648742327

# %%
df[df['order_id'] == 648742327]
# Out:
#             city  bar_id   order_id               order_time            title  \
# 130617  Gatineau    3478  648742327  2019-07-16 17:50:37.000          LASAGNE
# 130618  Gatineau    3478  648742327  2019-07-16 17:50:37.000       EX. GRATIN
# 130619  Gatineau    3478  648742327  2019-07-16 17:50:37.000     PIZZA-FRITES
# 130620  Gatineau    3478  648742327  2019-07-16 17:50:37.000    CLUB SANDWICH
# 130621  Gatineau    3478  648742327  2019-07-16 17:50:37.000      PETIT BLANC
# 130622  Gatineau    3478  648742327  2019-07-16 17:50:37.000          MESSAGE
# 130623  Gatineau    3478  648742327  2019-07-16 17:50:37.000          MESSAGE
# 130624  Gatineau    3478  648742327  2019-07-16 17:50:37.000         DIETCOKE
# 130625  Gatineau    3478  648742327  2019-07-16 17:50:37.000     BUD FUT 20OZ
# 130626  Gatineau    3478  648742327  2019-07-16 17:50:37.000  AVEC MAYONNAISE
# 130627  Gatineau    3478  648742327  2019-07-16 17:50:37.000     PATATE FRITE
#
#         category_id  beer_brand_id  beer_serving_type_id  beer_volume  \
# 130617          2.0              0                     0        0.000
# 130618          2.0              0                     0        0.000
# 130619          2.0              0                     0        0.000
# 130620          2.0              0                     0        0.000
# 130621          5.0              0                     0        0.000
# 130622          5.0              0                     0        0.000
# 130623          5.0              0                     0        0.000
# 130624          4.0              0                     0        0.000
# 130625          1.0             71                     2        0.591
# 130626          5.0              0                     0        0.000
# 130627          5.0              0                     0        0.000
#
#         item_qty  sales_before_tax  guest_count    bar_type
# 130617       1.0             15.00            3  Restaurant
# 130618       1.0              2.35            3  Restaurant
# 130619       1.0             11.95            3  Restaurant
# 130620       1.0             14.00            3  Restaurant
# 130621       1.0              0.00            3  Restaurant
# 130622       1.0              0.00            3  Restaurant
# 130623       1.0              0.00            3  Restaurant
# 130624       1.0              3.00            3  Restaurant
# 130625       1.0              6.05            3  Restaurant
# 130626       1.0              0.00            3  Restaurant
# 130627       1.0              0.00            3  Restaurant

# %% [markdown]
# July 16th (Tuesday), 17:50, 3 guests at a Restaurant.
#
# - 4 Dishes:
#   - 1 Lasagne
#   - 1 Gratin
#   - 1 Pizza
#   - 1 Club Sandwich
# - Drinks:
#   - 1 Diet Coke
#   - 2 Bud Beers
#
# `Social Gathering`

# %% [markdown]
# ### 14. Table 648792610

# %%
df[df['order_id'] == 648792610]
# Out:
#                city  bar_id   order_id               order_time  \
# 1256798  Saint John    3210  648792610  2019-07-16 19:48:00.000
# 1256799  Saint John    3210  648792610  2019-07-16 19:48:00.000
# 1256800  Saint John    3210  648792610  2019-07-16 19:48:00.000
# 1256801  Saint John    3210  648792610  2019-07-16 19:48:00.000
# 1256802  Saint John    3210  648792610  2019-07-16 19:48:00.000
# 1256803  Saint John    3210  648792610  2019-07-16 19:48:00.000
# 1256804  Saint John    3210  648792610  2019-07-16 19:48:00.000
# 1256805  Saint John    3210  648792610  2019-07-16 19:48:00.000
#
#                        title  category_id  beer_brand_id  \
# 1256798                   **          2.0              0
# 1256799  KID CHKN FINGER/POT          2.0              0
# 1256800      K PASTA/ BUTTER          2.0              0
# 1256801        KID ORANGE JC          4.0              0
# 1256802  6OZ PINOT LAS MORAS          6.0              0
# 1256803        GRANNY BURGER          2.0              0
# 1256804     pint COORS LIGHT          1.0            280
# 1256805  1/2 GRILLED LOBSTER          2.0              0
#
#          beer_serving_type_id  beer_volume  item_qty  sales_before_tax  \
# 1256798                     0        0.000       2.0              0.00
# 1256799                     0        0.000       1.0              7.95
# 1256800                     0        0.000       1.0              5.95
# 1256801                     0        0.000       2.0              3.00
# 1256802                     0        0.000       1.0              9.00
# 1256803                     0        0.000       1.0             17.99
# 1256804                     2        0.591       1.0              6.50
# 1256805                     0        0.000       1.0             30.00
#
#          guest_count    bar_type
# 1256798            3  Restaurant
# 1256799            3  Restaurant
# 1256800            3  Restaurant
# 1256801            3  Restaurant
# 1256802            3  Restaurant
# 1256803            3  Restaurant
# 1256804            3  Restaurant
# 1256805            3  Restaurant

# %% [markdown]
# July 16th (Tueday), 19:50, 3 guests at a restaurant.
#
# - 4 Main Dishes:
#   - 1 Kids Chicken Fingers
#   - 1 Kids Pasta
#   - 1 Burger
#   - 1 Grilled Lobster
# - 1 Beer:
#   - 1 Coors Light PINT
# - 2 Soft Drinks:
#   - 2 Kid Orange Juice
# - 1 Wine:
#   - 1 Las Moras Pinot
#
# `Dinner`, a parent with both of his children.

# %% [markdown]
# ### 15. Table 650470064

# %%
df[df['order_id'] == 650470064]
# Out:
#                  city  bar_id   order_id               order_time  \
# 517007  Saint-Georges   19531  650470064  2019-07-18 18:40:07.000
# 517008  Saint-Georges   19531  650470064  2019-07-18 18:40:07.000
# 517009  Saint-Georges   19531  650470064  2019-07-18 18:40:07.000
#
#                    title  category_id  beer_brand_id  beer_serving_type_id  \
# 517007         MOKA FRIO          3.0              0                     0
# 517008         LE SHAMAN          3.0              0                     0
# 517009  TRIO DE TARTARES          2.0              0                     0
#
#         beer_volume  item_qty  sales_before_tax  guest_count bar_type
# 517007          0.0       1.0          9.315452            3  Bar/Pub
# 517008          0.0       1.0          9.315452            3  Bar/Pub
# 517009          0.0       1.0         38.329096            3  Bar/Pub

# %% [markdown]
# July 18th (Thursday), 18:40, 3 guests at a Bar/Pub.
#
# - 1 Main Dish:
#   - 1 Tartar (Trio de Tartares)
# - 2 Cocktails:
#   - 1 Moka Frio
#   - 1 Le Shaman
#
# `After Work`

# %% [markdown]
# ### 16. Table 648887570

# %%
df[df['order_id'] == 648887570]
# Out:
#             city  bar_id   order_id               order_time  \
# 763014  Montreal    9438  648887570  2019-07-16 19:18:15.000
# 763015  Montreal    9438  648887570  2019-07-16 19:18:15.000
# 763016  Montreal    9438  648887570  2019-07-16 19:18:15.000
# 763017  Montreal    9438  648887570  2019-07-16 19:18:15.000
# 763018  Montreal    9438  648887570  2019-07-16 19:18:15.000
# 763019  Montreal    9438  648887570  2019-07-16 19:18:15.000
#
#                     title  category_id  beer_brand_id  beer_serving_type_id  \
# 763014  TARTE FINE BOUDIN          2.0              0                     0
# 763015   CALVADOS BOULARD          3.0              0                     0
# 763016       MIJOTE CARTE          2.0              0                     0
# 763017   FEUILLETE HOMARD          2.0              0                     0
# 763018       CREME BRULEE          2.0              0                     0
# 763019  TARTARE CREVETTES          2.0              0                     0
#
#         beer_volume  item_qty  sales_before_tax  guest_count bar_type
# 763014          0.0       1.0              14.0            3      NaN
# 763015          0.0       1.0              12.0            3      NaN
# 763016          0.0       1.0              25.0            3      NaN
# 763017          0.0       1.0              38.0            3      NaN
# 763018          0.0       1.0               9.0            3      NaN
# 763019          0.0       1.0              16.0            3      NaN

# %% [markdown]
# July 16th (Tuesday), 19:20, 3 guests.
#
# - 5 Main Dishes:
#   - 1 Tartar (Tarte Fine Boudin)
#   - 1 Meat Pie (Mijote Carte)
#   - 1 Lobster (Feuillete Homard)
#   - 1 Creme Brulee
#   - 1 Shrimp Tartar (Tartare Crevettes)
# - 1 Alcoholic Drink:
#   - 1 Calvados Boulard
#
# `Dinner`

# %% [markdown]
# ### 17. Table 651921155

# %%
df[df['order_id'] == 651921155]
# Out:
#              city  bar_id   order_id               order_time         title  \
# 393268  Vancouver   11290  651921155  2019-07-20 18:48:00.000  PINT FAT TUG
# 393269  Vancouver   11290  651921155  2019-07-20 18:48:00.000  PINT FAT TUG
#
#         category_id  beer_brand_id  beer_serving_type_id  beer_volume  \
# 393268          1.0           2388                     2        0.473
# 393269          1.0           2388                     2        0.473
#
#         item_qty  sales_before_tax  guest_count bar_type
# 393268       1.0               8.0            3  Bar/Pub
# 393269       1.0               8.0            3  Bar/Pub

# %% [markdown]
# July 20th (Saturday), 18:50, 3 guests at a Bar/Pub.
#
# - 2 Fat Tug Beer PINTs
#
# `Drinking`

# %% [markdown]
# ### 18. Table 650194788

# %%
df[df['order_id'] == 650194788]
# Out:
#                city  bar_id   order_id               order_time  \
# 1597884  Saint John    3211  650194788  2019-07-18 19:48:33.000
# 1597885  Saint John    3211  650194788  2019-07-18 19:48:33.000
# 1597886  Saint John    3211  650194788  2019-07-18 19:48:33.000
# 1597887  Saint John    3211  650194788  2019-07-18 19:48:33.000
# 1597888  Saint John    3211  650194788  2019-07-18 19:48:33.000
# 1597889  Saint John    3211  650194788  2019-07-18 19:48:33.000
# 1597890  Saint John    3211  650194788  2019-07-18 19:48:33.000
#
#                        title  category_id  beer_brand_id  \
# 1597884         PITA  NACHOS          2.0              0
# 1597885   KID'S MAC N CHEESE          2.0              0
# 1597886  SWEET CHILI\SOUR CR          2.0              0
# 1597887            FISH/CHIP          2.0              0
# 1597888   BUTTERMILK CHICKEN          2.0              0
# 1597889                GRAVY          2.0              0
# 1597890      NO DRINK ******          4.0              0
#
#          beer_serving_type_id  beer_volume  item_qty  sales_before_tax  \
# 1597884                     0          0.0       1.0             17.00
# 1597885                     0          0.0       1.0              8.00
# 1597886                     0          0.0       1.0              0.69
# 1597887                     0          0.0       1.0             16.50
# 1597888                     0          0.0       1.0             16.50
# 1597889                     0          0.0       2.0              7.00
# 1597890                     0          0.0       2.0              0.00
#
#          guest_count bar_type
# 1597884            3  Bar/Pub
# 1597885            3  Bar/Pub
# 1597886            3  Bar/Pub
# 1597887            3  Bar/Pub
# 1597888            3  Bar/Pub
# 1597889            3  Bar/Pub
# 1597890            3  Bar/Pub

# %% [markdown]
# July 18th (Thursday), 19:50, 3 guests at a Bar/Pub.
#
# - 4 Dishes:
#   - 1 Pita Nachos
#   - 1 Kids Mac N Cheese
#   - 1 Fish N Chips
#   - 1 Buttermilk Chicken
#
# `Dinner`

# %% [markdown]
# ### 19. Table 648917154

# %%
df[df['order_id'] == 648917154]
# Out:
#             city  bar_id   order_id               order_time          title  \
# 475633  Victoria    9446  648917154  2019-07-16 23:06:00.000        FAT TUG
# 475634  Victoria    9446  648917154  2019-07-16 23:06:00.000  BEEFEATER DBL
# 475635  Victoria    9446  648917154  2019-07-16 23:06:00.000    ABSOLUT DBL
# 475636  Victoria    9446  648917154  2019-07-16 23:06:00.000          SHAFT
# 475637  Victoria    9446  648917154  2019-07-16 23:06:00.000          SHAFT
# 475638  Victoria    9446  648917154  2019-07-16 23:06:00.000          SHAFT
#
#         category_id  beer_brand_id  beer_serving_type_id  beer_volume  \
# 475633          1.0           2388                     2        0.591
# 475634          3.0              0                     0        0.000
# 475635          3.0              0                     0        0.000
# 475636          3.0              0                     0        0.000
# 475637          3.0              0                     0        0.000
# 475638          3.0              0                     0        0.000
#
#         item_qty  sales_before_tax  guest_count bar_type
# 475633       1.0              6.52            3  Bar/Pub
# 475634       1.0              7.83            3  Bar/Pub
# 475635       1.0              6.52            3  Bar/Pub
# 475636       1.0              6.52            3  Bar/Pub
# 475637       1.0              6.52            3  Bar/Pub
# 475638       1.0              6.52            3  Bar/Pub

# %% [markdown]
# July 16th (Tuesday), 23:06, 3 guests at a Bar/Pub.
#
# - 1 Fat Tug Beer
# - 5 Cocktails:
#   - 1 Beefeater
#   - 1 Absolut
#   - 3 Shafts
#
# `Drinking`, definitely.

# %% [markdown]
# ### 20. Table 651992091

# %%
df[df['order_id'] == 651992091]
# Out:
#              city  bar_id   order_id               order_time  \
# 393092  Vancouver   11290  651992091  2019-07-20 20:54:00.000
# 393093  Vancouver   11290  651992091  2019-07-20 20:54:00.000
# 393094  Vancouver   11290  651992091  2019-07-20 20:54:00.000
# 393095  Vancouver   11290  651992091  2019-07-20 20:54:00.000
# 393096  Vancouver   11290  651992091  2019-07-20 20:54:00.000
#
#                    title  category_id  beer_brand_id  beer_serving_type_id  \
# 393092   PINT WOBBLY POP          1.0           2374                     2
# 393093    JUG STEAMWORKS          1.0           2524                     2
# 393094  **FIRST DRINKS**          5.0              0                     0
# 393095     QUESO CHS DIP          2.0              0                     0
# 393096       SHARK BITES          2.0              0                     0
#
#         beer_volume  item_qty  sales_before_tax  guest_count bar_type
# 393092         0.59       1.0              8.00            3  Bar/Pub
# 393093         1.77       1.0             21.00            3  Bar/Pub
# 393094         0.00       1.0              0.00            3  Bar/Pub
# 393095         0.00       1.0             13.75            3  Bar/Pub
# 393096         0.00       1.0             14.00            3  Bar/Pub

# %% [markdown]
# July 20th (Saturday), 20:54, 3 guests at a Bar/Pub.
#
# - 2 Dishes:
#   - 1 Cheese Dip
#   - 1 Shark Bites
# - 4 Beers:
#   - 2 Wobbly Pop PINT
#   - 2 Steamworks JUG
#
# `Social Gathering`

# %% [markdown]
# ----

# %% [markdown]
# ### Annotations - All Over Again, with no french-speaking cities

# %% [markdown]
# -----

# %% [markdown]
# ### Summary
#
# To my opinion, the following occasions are useless:
# - `After Work`
#
#
# On the other hand, we should add the following new occasions:
# - `Lunch`
