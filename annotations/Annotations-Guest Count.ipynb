# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("data/df_july.csv")

# %%
df.drop("country",axis=1,inplace=True) # only single country, no need
df = df[df["bar_type"]!= "Night Club"] # only 83 rows from Night Club 
df.drop(["data_availability_status_id","is_bulk","status","last_status","state","state_id","waiter_id","country_id"],axis=1,inplace=True) # only single country, no need

# %%
df = df[df["city"] == "Toronto"] #choose only Toronto city

# %%
to_annotate = [650787215,
 651998706,
 650333616,
 650818052,
 649560864,
 647613485,
 648222217,
 649425742,
 651615952,
 647672113,
 649463242,
 650181148,
 649564380,
 650180753,
 651832746,
 650199721,
 649130084,
 650371983,
 649191153,
 649403570]

# %%
df[df["order_id"] == 650787215]
# Out:
#            city  bar_id   order_id               order_time  order_item_id  \
# 436890  Toronto    4682  650787215  2019-07-19 12:44:55.000    65078721500
#
#                   title  category_id  beer_brand_id  beer_serving_type_id  \
# 436890  Poutine Takeout          2.0              0                     0
#
#         beer_volume  item_qty  sales_before_tax  sales_inc_tax  guest_count  \
# 436890          0.0       1.0              4.99           5.64            1
#
#                timezone  bar_type_id bar_type
# 436890  America/Toronto            1  Bar/Pub

# %% [markdown]
# ## estimated guest counts:
# ### karin: 1
# ### ofer: 1
# ### daniela: 1
# ### ortal:
# ### ron: 1
#
# Resolution: 1

# %% [markdown]
# Notes:

# %%
df[df["order_id"] == 651998706]
# Out:
#            city  bar_id   order_id               order_time  order_item_id  \
# 469195  Toronto    1279  651998706  2019-07-20 22:12:00.000    65199870605
# 469196  Toronto    1279  651998706  2019-07-20 22:12:00.000    65199870613
# 469197  Toronto    1279  651998706  2019-07-20 22:12:00.000    65199870606
# 469198  Toronto    1279  651998706  2019-07-20 22:12:00.000    65199870615
# 469199  Toronto    1279  651998706  2019-07-20 22:12:00.000    65199870608
# 469200  Toronto    1279  651998706  2019-07-20 22:12:00.000    65199870609
# 469201  Toronto    1279  651998706  2019-07-20 22:12:00.000    65199870602
# 469202  Toronto    1279  651998706  2019-07-20 22:12:00.000    65199870603
# 469203  Toronto    1279  651998706  2019-07-20 22:12:00.000    65199870601
# 469204  Toronto    1279  651998706  2019-07-20 22:12:00.000    65199870610
# 469205  Toronto    1279  651998706  2019-07-20 22:12:00.000    65199870614
# ...

# %%
#df[df["bar_id"]== 1279].head(10)
#pay attention dont count on the time difference, all orders per table have the same order time

# %% [markdown]
# ## estimated guest counts:
# ### karin: 10
# ### ofer: 5
# ### daniela: 8
# ### ortal:
# ### ron: 5
#
# Resolution: 5-10

# %% [markdown]
# Notes:
#
#     11 - liquer drinks (not beer or wine)
#
#     2 - food items
#
#     What does the * mean next to the jameson?
#     price would help:(, also knowing the beer_serving_id for the beer.
#     Itd be helpful if we knew which were actual drinks and which were poured as shots. At least the size of the
#     pour could tell us, since shots are always poured per person.

# %%
df[df["order_id"] == 650333616]
# Out:
#             city  bar_id   order_id               order_time  order_item_id  \
# 1572277  Toronto   17655  650333616  2019-07-18 21:47:00.000    65033361600
# 1572278  Toronto   17655  650333616  2019-07-18 21:47:00.000    65033361602
# 1572279  Toronto   17655  650333616  2019-07-18 21:47:00.000    65033361601
#
#                title  category_id  beer_brand_id  beer_serving_type_id  \
# 1572277  KEITH'S TAP          1.0            217                     2
# 1572278  KEITH'S TAP          1.0            217                     2
# 1572279  KEITH'S TAP          1.0            217                     2
#
#          beer_volume  item_qty  sales_before_tax  sales_inc_tax  guest_count  \
# 1572277         0.37       1.0               7.0           7.91            1
# 1572278         0.37       1.0               7.0           7.91            1
# 1572279         0.37       1.0               7.0           7.91            1
#
#                 timezone  bar_type_id bar_type
# ...

# %% [markdown]
# ## estimated guest counts:
# ### karin: 2
# ### ofer: 3
# ### daniela: 3
# ### ortal:
# ### ron: 3
#
# Resolution: 3

# %% [markdown]
# Notes:
#
#     since the beer size is 1/3, I would assume its more likely to be three people,
#     rather than one person drinking two 1/3 and one drinks 1/3.
#     obviously purely speculative.

# %%
df[df["order_id"] == 650818052]
# Out:
#             city  bar_id   order_id               order_time  order_item_id  \
# 1574737  Toronto   23193  650818052  2019-07-19 13:08:06.000    65081805204
# 1574738  Toronto   23193  650818052  2019-07-19 13:08:06.000    65081805202
# 1574739  Toronto   23193  650818052  2019-07-19 13:08:06.000    65081805201
# 1574740  Toronto   23193  650818052  2019-07-19 13:08:06.000    65081805205
# 1574741  Toronto   23193  650818052  2019-07-19 13:08:06.000    65081805203
# 1574742  Toronto   23193  650818052  2019-07-19 13:08:06.000    65081805200
#
#                             title  category_id  beer_brand_id  \
# 1574737          Pint Coors Light          1.0            280
# 1574738     Chicken Fingers SAUCE          2.0              0
# 1574739           Chicken Fingers          2.0              0
# 1574740                       Pop          4.0              0
# 1574741                +add Gravy          2.0              0
# ...

# %% [markdown]
# ## estimated guest counts:
# ### karin: 2
# ### ofer: 2
# ### daniela: 2
# ### ortal:
# ### ron: 2
#
# Resolution: 2

# %% [markdown]
# Notes:
#
#     Two drinks and two meals events out to two people

# %%
df[df["order_id"] == 649560864]
# Out:
#             city  bar_id   order_id               order_time  order_item_id  \
# 1372306  Toronto    1279  649560864  2019-07-17 16:32:00.000    64956086400
#
#            title  category_id  beer_brand_id  beer_serving_type_id  \
# 1372306  BEACHED          3.0              0                     0
#
#          beer_volume  item_qty  sales_before_tax  sales_inc_tax  guest_count  \
# 1372306          0.0       1.0               0.0            0.0            0
#
#                 timezone  bar_type_id       bar_type
# 1372306  America/Toronto           10  Casual Dining

# %% [markdown]
# ## estimated guest counts:
# ### karin: 1
# ### ofer: 1
# ### daniela: 1
# ### ortal:
# ### ron: 1
#
# Resolution: 1

# %%
df[df["order_id"] == 647613485]
# Out:
#            city  bar_id   order_id               order_time  order_item_id  \
# 336934  Toronto   17650  647613485  2019-07-14 20:06:00.000    64761348500
# 336935  Toronto   17650  647613485  2019-07-14 20:06:00.000    64761348501
# 336936  Toronto   17650  647613485  2019-07-14 20:06:00.000    64761348502
#
#               title  category_id  beer_brand_id  beer_serving_type_id  \
# 336934  CAPT SPICED          3.0              0                     0
# 336935     CALAMARI          2.0              0                     0
# 336936    SPAGHETTI          2.0              0                     0
#
#         beer_volume  item_qty  sales_before_tax  sales_inc_tax  guest_count  \
# 336934          0.0       1.0              6.50       7.344293            1
# 336935          0.0       1.0              5.95       6.722853            1
# 336936          0.0       1.0              5.95       6.722853            1
#
#                timezone  bar_type_id bar_type
# ...

# %% [markdown]
# ## estimated guest counts:
# ### karin: 2
# ### ofer: 2
# ### daniela: 2
# ### ortal:
# ### ron: 2
#
# Resolution: 2

# %%
df[df["order_id"] == 648222217]
# Out:
#            city  bar_id   order_id               order_time  order_item_id  \
# 156005  Toronto    1177  648222217  2019-07-15 18:26:00.000    64822221700
# 156006  Toronto    1177  648222217  2019-07-15 18:26:00.000    64822221706
# 156007  Toronto    1177  648222217  2019-07-15 18:26:00.000    64822221705
# 156008  Toronto    1177  648222217  2019-07-15 18:26:00.000    64822221707
# 156009  Toronto    1177  648222217  2019-07-15 18:26:00.000    64822221708
# 156010  Toronto    1177  648222217  2019-07-15 18:26:00.000    64822221704
# 156011  Toronto    1177  648222217  2019-07-15 18:26:00.000    64822221701
# 156012  Toronto    1177  648222217  2019-07-15 18:26:00.000    64822221703
# 156013  Toronto    1177  648222217  2019-07-15 18:26:00.000    64822221702
#
#              title  category_id  beer_brand_id  beer_serving_type_id  \
# 156005  CORONA BTL          1.0            128                     1
# 156006  CORONA BTL          1.0            128                     1
# ...

# %% [markdown]
# ## estimated guest counts:
# ### karin: 6
# ### ofer: 3
# ### daniela: 3
# ### ortal:
# ### ron: 3
#
# Resolution: 3-5

# %% [markdown]
# Notes:
#
#     Since theres only one order of wings and fries (the other WINGS is a sauce most likely since it doesn't cost anything), maybe more likely that three people had a second round.

# %%
df[df["order_id"] == 649425742]
# Out:
#            city  bar_id   order_id               order_time  order_item_id  \
# 731294  Toronto    1279  649425742  2019-07-17 18:53:00.000    64942574201
# 731295  Toronto    1279  649425742  2019-07-17 18:53:00.000    64942574206
# 731296  Toronto    1279  649425742  2019-07-17 18:53:00.000    64942574203
# 731297  Toronto    1279  649425742  2019-07-17 18:53:00.000    64942574205
# 731298  Toronto    1279  649425742  2019-07-17 18:53:00.000    64942574202
# 731299  Toronto    1279  649425742  2019-07-17 18:53:00.000    64942574200
# 731300  Toronto    1279  649425742  2019-07-17 18:53:00.000    64942574204
#
#                     title  category_id  beer_brand_id  beer_serving_type_id  \
# 731294           V.CAESAR          4.0              0                     0
# 731295  $Sub.Swt.Pot.Fry-          2.0              0                     0
# 731296     LONG.NACHO.VEG          2.0              0                     0
# ...

# %% [markdown]
# ## estimated guest counts:
# ### karin: 3
# ### ofer: 2
# ### daniela: 2
# ### ortal:
# ### ron: 2
#
# Resolution: 2

# %%
df[df["order_id"] == 651615952]
# Out:
#           city  bar_id   order_id               order_time  order_item_id  \
# 33577  Toronto    1276  651615952  2019-07-20 12:11:00.000    65161595201
# 33578  Toronto    1276  651615952  2019-07-20 12:11:00.000    65161595202
# 33579  Toronto    1276  651615952  2019-07-20 12:11:00.000    65161595200
#
#                   title  category_id  beer_brand_id  beer_serving_type_id  \
# 33577  HOLY.SMOKE.BURGR          2.0              0                     0
# 33578      S/O.Bf.Gravy          2.0              0                     0
# 33579     HOEGAARDEN.XL          1.0             59                     2
#
#        beer_volume  item_qty  sales_before_tax  sales_inc_tax  guest_count  \
# 33577        0.000       1.0             17.97      20.307224            1
# 33578        0.000       1.0              1.49       1.683793            1
# 33579        0.591       1.0             10.91      12.328983            1
#
#               timezone  bar_type_id       bar_type
# ...

# %% [markdown]
# ## estimated guest counts:
# ### karin: 1
# ### ofer: 2
# ### daniela: 1
# ### ortal:
# ### ron: 1
#
# Resolution: 1

# %%
df[df["order_id"] == 647672113]
# Out:
#            city  bar_id   order_id               order_time  order_item_id  \
# 890268  Toronto    1175  647672113  2019-07-14 20:48:00.000    64767211302
# 890269  Toronto    1175  647672113  2019-07-14 20:48:00.000    64767211300
# 890270  Toronto    1175  647672113  2019-07-14 20:48:00.000    64767211304
# 890271  Toronto    1175  647672113  2019-07-14 20:48:00.000    64767211301
# 890272  Toronto    1175  647672113  2019-07-14 20:48:00.000    64767211303
#
#                   title  category_id  beer_brand_id  beer_serving_type_id  \
# 890268    OLD FASHIONED          3.0              0                     0
# 890269    BCKT.4.CORONA          1.0            128                     1
# 890270  n/c.nacho.chips          2.0              0                     0
# 890271        TUNA.GUAC          2.0              0                     0
# 890272    MAKERS.MARK..          3.0              0                     0
#
# ...

# %% [markdown]
# ## estimated guest counts:
# ### karin: 2
# ### ofer: 4
# ### daniela: 3
# ### ortal:
# ### ron: 4
#
# Resolution: 3-5

# %% [markdown]
# Notes:
#
#     To me it looks like it could be either 3 people or 5 people. I think it makes sense that either two people are sharing
#     a beer caraff plus one person who ordered hard liquer, or 4 people are sharing the beer caraff, and still one more person ordered a liquer.
#     I chose three people because they are sharing a single food plate.
#
#     ron: it seems to me that `BCKT.4.CORONA` is a bucket of 4 corona bottles (a quick google search)

# %%
df[df["order_id"] == 649463242]
# Out:
#            city  bar_id   order_id               order_time  order_item_id  \
# 601059  Toronto    1177  649463242  2019-07-17 20:18:00.000    64946324203
# 601060  Toronto    1177  649463242  2019-07-17 20:18:00.000    64946324204
# 601061  Toronto    1177  649463242  2019-07-17 20:18:00.000    64946324206
# 601062  Toronto    1177  649463242  2019-07-17 20:18:00.000    64946324208
# 601063  Toronto    1177  649463242  2019-07-17 20:18:00.000    64946324202
# 601064  Toronto    1177  649463242  2019-07-17 20:18:00.000    64946324200
# 601065  Toronto    1177  649463242  2019-07-17 20:18:00.000    64946324205
# 601066  Toronto    1177  649463242  2019-07-17 20:18:00.000    64946324209
# 601067  Toronto    1177  649463242  2019-07-17 20:18:00.000    64946324207
# 601068  Toronto    1177  649463242  2019-07-17 20:18:00.000    64946324201
#
#                   title  category_id  beer_brand_id  beer_serving_type_id  \
# ...

# %% [markdown]
# ## estimated guest counts:
# ### karin: 4
# ### ofer: 4
# ### daniela: 2
# ### ortal:
# ### ron: 2
#
# Resolution: 3-5

# %% [markdown]
# Notes:
#
#     I chose two haha because to me it looks like only two people ordered water (usually you bring water for the whole table)
#     and a double order of the same drink, maybe two people having a second round?
#     Maybe even a data, since they have a single plate of food, and then share dessert.

# %%
df[df["order_id"] == 650181148]
# Out:
#             city  bar_id   order_id               order_time  order_item_id  \
# 1268593  Toronto    1154  650181148  2019-07-18 16:24:00.000    65018114802
# 1268594  Toronto    1154  650181148  2019-07-18 16:24:00.000    65018114805
# 1268595  Toronto    1154  650181148  2019-07-18 16:24:00.000    65018114804
# 1268596  Toronto    1154  650181148  2019-07-18 16:24:00.000    65018114800
# 1268597  Toronto    1154  650181148  2019-07-18 16:24:00.000    65018114801
# 1268598  Toronto    1154  650181148  2019-07-18 16:24:00.000    65018114803
#
#                    title  category_id  beer_brand_id  beer_serving_type_id  \
# 1268593    BCKT.4.CORONA          1.0            128                     1
# 1268594       CORONA BTL          1.0            128                     1
# 1268595       CORONA BTL          1.0            128                     1
# 1268596    BCKT.4.CORONA          1.0            128                     1
# ...

# %% [markdown]
# ## estimated guest counts:
# ### karin: 3
# ### ofer: 5
# ### daniela:
# ### ortal:
# ### ron: 5
#
# Resolution: 5-10

# %% [markdown]
# Notes:
#
#     So, again, we have 2 x `BCKT.4.CORONA` + 2 corona bottles to the total of 10 corona bottles

# %%
df[df["order_id"] == 649564380]
# Out:
#             city  bar_id   order_id               order_time  order_item_id  \
# 1444552  Toronto   12543  649564380  2019-07-18 01:10:00.000    64956438000
#
#             title  category_id  beer_brand_id  beer_serving_type_id  \
# 1444552  1LB WING          2.0              0                     0
#
#          beer_volume  item_qty  sales_before_tax  sales_inc_tax  guest_count  \
# 1444552          0.0       1.0              15.0          16.95            1
#
#                 timezone  bar_type_id bar_type
# 1444552  America/Toronto            1  Bar/Pub

# %% [markdown]
# ## estimated guest counts:
# ### karin: 1
# ### ofer: 1
# ### daniela:
# ### ortal:
# ### ron: 1
#
# Resolution: 1

# %%
df[df["order_id"] == 650180753]
# Out:
#            city  bar_id   order_id               order_time  order_item_id  \
# 278044  Toronto   17199  650180753  2019-07-18 17:58:00.000    65018075301
# 278045  Toronto   17199  650180753  2019-07-18 17:58:00.000    65018075303
# 278046  Toronto   17199  650180753  2019-07-18 17:58:00.000    65018075302
# 278047  Toronto   17199  650180753  2019-07-18 17:58:00.000    65018075300
#
#                 title  category_id  beer_brand_id  beer_serving_type_id  \
# 278044  APEROL.SPRITZ          3.0              0                     0
# 278045  APEROL.SPRITZ          3.0              0                     0
# 278046  APEROL.SPRITZ          3.0              0                     0
# 278047  APEROL.SPRITZ          3.0              0                     0
#
#         beer_volume  item_qty  sales_before_tax  sales_inc_tax  guest_count  \
# 278044          0.0       1.0              12.0          13.56            0
# ...

# %% [markdown]
# ## estimated guest counts:
# ### karin: 3
# ### ofer: 4
# ### daniela:
# ### ortal:
# ### ron: 4
#
# Resolution: 3-5

# %%
df[df["order_id"] == 651832746]
# Out:
#           city  bar_id   order_id               order_time  order_item_id  \
# 13268  Toronto    1177  651832746  2019-07-20 20:01:00.000    65183274600
# 13269  Toronto    1177  651832746  2019-07-20 20:01:00.000    65183274602
# 13270  Toronto    1177  651832746  2019-07-20 20:01:00.000    65183274601
#
#                  title  category_id  beer_brand_id  beer_serving_type_id  \
# 13268       OBAN.14YR*          3.0              0                     0
# 13269  Salmon.Rice/Veg          2.0              0                     0
# 13270    SMOKIN.SALMON          2.0              0                     0
#
#        beer_volume  item_qty  sales_before_tax  sales_inc_tax  guest_count  \
# 13268          0.0       2.0             24.31      27.468462            1
# 13269          0.0       1.0              1.99       2.248550            1
# 13270          0.0       1.0             23.96      27.072988            1
#
#               timezone  bar_type_id       bar_type
# ...

# %% [markdown]
# ## estimated guest counts:
# ### karin: 2
# ### ofer: 2
# ### daniela: 2
# ### ortal:
# ### ron: 2
#
# Resolution: 2

# %%
df[df["order_id"] == 650199721]
# Out:
#             city  bar_id   order_id               order_time  order_item_id  \
# 1304093  Toronto   17199  650199721  2019-07-18 17:57:00.000    65019972100
# 1304094  Toronto   17199  650199721  2019-07-18 17:57:00.000    65019972107
# 1304095  Toronto   17199  650199721  2019-07-18 17:57:00.000    65019972102
# 1304096  Toronto   17199  650199721  2019-07-18 17:57:00.000    65019972104
# 1304097  Toronto   17199  650199721  2019-07-18 17:57:00.000    65019972105
# 1304098  Toronto   17199  650199721  2019-07-18 17:57:00.000    65019972101
# 1304099  Toronto   17199  650199721  2019-07-18 17:57:00.000    65019972106
# 1304100  Toronto   17199  650199721  2019-07-18 17:57:00.000    65019972103
#
#                    title  category_id  beer_brand_id  beer_serving_type_id  \
# 1304093      GIN.DYNAMIC          3.0              0                     0
# 1304094       HENDRICKS*          3.0              0                     0
# ...

# %% [markdown]
# ## estimated guest counts:
# ### karin: 4
# ### ofer: 2
# ### daniela: 2-5
# ### ortal:
# ### ron: 2 (? could be 5)
#
# Resolution: 3-5

# %% [markdown]
# Notes:
#
#     I wanted to say two people since there are two main drinks, a single expensive food plate, and a few small ones (maybe starters). But there are 4 dishes that are divided in their item quantity by 5 people, should there be five people? Really unsure

# %%
df[df["order_id"] == 649130084]
# Out:
#            city  bar_id   order_id               order_time  order_item_id  \
# 556275  Toronto    4682  649130084  2019-07-17 10:13:52.000    64913008400
#
#                 title  category_id  beer_brand_id  beer_serving_type_id  \
# 556275  Thick Pastram          2.0              0                     0
#
#         beer_volume  item_qty  sales_before_tax  sales_inc_tax  guest_count  \
# 556275          0.0       1.0             18.98          21.45            1
#
#                timezone  bar_type_id bar_type
# 556275  America/Toronto            1  Bar/Pub

# %% [markdown]
# ## estimated guest counts:
# ### karin: 1
# ### ofer: 1
# ### daniela: 1
# ### ortal:
# ### ron: 1
#
# Resolution: 1

# %%
df[df["order_id"] == 650371983]
# Out:
#            city  bar_id   order_id               order_time  order_item_id  \
# 320056  Toronto    1175  650371983  2019-07-17 21:07:00.000    65037198300
#
#                  title  category_id  beer_brand_id  beer_serving_type_id  \
# 320056  FINGERS.SAUCED          2.0              0                     0
#
#         beer_volume  item_qty  sales_before_tax  sales_inc_tax  guest_count  \
# 320056          0.0       1.0               0.0            0.0            1
#
#                timezone  bar_type_id       bar_type
# 320056  America/Toronto           10  Casual Dining

# %% [markdown]
# ## estimated guest counts:
# ### karin: 1
# ### ofer: 1
# ### daniela: 1
# ### ortal:
# ### ron: 1
#
# Resolution: 1

# %%
df[df["order_id"] == 649191153]
# Out:
#             city  bar_id   order_id               order_time  order_item_id  \
# 1579591  Toronto   17271  649191153  2019-07-17 11:45:00.000    64919115302
# 1579592  Toronto   17271  649191153  2019-07-17 11:45:00.000    64919115301
# 1579593  Toronto   17271  649191153  2019-07-17 11:45:00.000    64919115300
#
#                    title  category_id  beer_brand_id  beer_serving_type_id  \
# 1579591     CAESAR VODKA          3.0              0                     0
# 1579592  CHIANG MAI BOWL          2.0              0                     0
# 1579593        YAM FRIES          2.0              0                     0
#
#          beer_volume  item_qty  sales_before_tax  sales_inc_tax  guest_count  \
# 1579591          0.0       1.0              7.50       8.473441            1
# 1579592          0.0       1.0              8.20       9.264296            1
# 1579593          0.0       1.0              5.95       6.722263            1
#
#                 timezone  bar_type_id bar_type
# ...

# %% [markdown]
# ## estimated guest counts:
# ### karin: 2
# ### ofer: 2
# ### daniela: 1
# ### ortal:
# ### ron: 1
#
# Resolution: 1-2 (new category)

# %% [markdown]
# Notes:
#
#     Since this is lunch time, I don't see how two people would share a single bowl with fries. Then again, would a person alone
#     order vodka? :P

# %%
df[df["order_id"] == 649403570]
# Out:
#             city  bar_id   order_id               order_time  order_item_id  \
# 1455356  Toronto    4268  649403570  2019-07-17 17:46:51.000    64940357000
#
#              title  category_id  beer_brand_id  beer_serving_type_id  \
# 1455356  FLAT ROOF          6.0              0                     0
#
#          beer_volume  item_qty  sales_before_tax  sales_inc_tax  guest_count  \
# 1455356          0.0       2.0             16.82          19.01            1
#
#                 timezone  bar_type_id bar_type
# 1455356  America/Toronto            0      NaN

# %% [markdown]
# ## estimated guest counts:
# ### karin: 1
# ### ofer: 1
# ### daniela: 1
# ### ortal:
# ### ron: 1
#
# Resolution: 1
