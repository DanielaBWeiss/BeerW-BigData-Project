# %%
# in this code i add kids feature and birthday feature
# I also filtered out unnecessary items from category 2

# %%
# full script: 

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

def filter_titles(title):
    if "extra" in title:
        return False
    elif "add" in title:
        return False
    elif "sauce" in title:
        return False
    elif "no " in title:
        return False
    elif "no." in title:
        return False
    elif "-no " in title:
        return False
    elif "side " in title:
        return False
    elif "+" in title:
        return False
    elif "dip" in title:
        return False
    elif "blue cheese" in title:
        return False
    elif "bbq" in title:
        return False
    elif "n/c" in title:
        return False
    elif "s/o" in title:
        return False
    elif title == '' or title == 'garlic.aioli' or title == 'gluten' or title == 'hot n honey' or title == 'honey garlic' or title == 'kids.' or title == 'to go':
        return False
    else:
        return True

df = pd.read_csv("data/df_july.csv")
df['order_time'] = pd.to_datetime(df['order_time'], format='%Y-%m-%d %H:%M:%S.%f')
df.drop("country",axis=1,inplace=True) # only single country, no need
df = df[df["bar_type"]!= "Night Club"] # only 83 rows from Night Club 
df.drop(["data_availability_status_id","is_bulk","status","last_status","state","state_id","waiter_id","country_id"],axis=1,inplace=True) # only single country, no need
df = df.loc[df.city == "Toronto"] #choose only Toronto city and only category 5
# remove unnecessary characters from title
whitelist = set('.abcdefghijklmnopqrstuvwxyz \\//')
df["title"] = df["title"].apply(lambda x: ''.join(filter(whitelist.__contains__ ,x.lower())))
df["kids_meal"] = df.title.apply(lambda x: 1 if 'kid' in x else 0)
df["birthday"] = df.title.apply(lambda x: 1 if 'birthday' in x else 0)
df = df[~((df['category_id'] == 2) & (df['title'].map(filter_titles) == False))]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("data/df_july.csv")

# %%
df['order_time'] = pd.to_datetime(df['order_time'], format='%Y-%m-%d %H:%M:%S.%f')

# %%
df.drop("country",axis=1,inplace=True) # only single country, no need
df = df[df["bar_type"]!= "Night Club"] # only 83 rows from Night Club 
df.drop(["data_availability_status_id","is_bulk","status","last_status","state","state_id","waiter_id","country_id"],axis=1,inplace=True) # only single country, no need
df = df.loc[df.city == "Toronto"] #choose only Toronto city and only category 5

# %%
# remove unnecessary characters from title
whitelist = set('.abcdefghijklmnopqrstuvwxyz \\//')
df["title"] = df["title"].apply(lambda x: ''.join(filter(whitelist.__contains__ ,x.lower())))

# %%
df["kids_meal"] = df.title.apply(lambda x: 1 if 'kid' in x else 0)
df["birthday"] = df.title.apply(lambda x: 1 if 'birthday' in x else 0)

# %%
print(df.kids_meal.sum())
print(df.birthday.sum())
# Out:
# 6046
# 322

# %%
df_category2 = df.loc[df.category_id == 2] #choose only category 2

# %%
print(df_category2.shape)
df_category2.head()
# Out:
# (152031, 19)
#         city  bar_id   order_id          order_time  order_item_id  \
# 76   Toronto   17125  649947220 2019-07-18 12:46:00    64994722005
# 90   Toronto    3379  650212816 2019-07-18 20:49:39    65021281601
# 139  Toronto   17125  649881063 2019-07-18 11:43:00    64988106300
# 178  Toronto    3379  650228446 2019-07-18 21:42:34    65022844604
# 179  Toronto   17125  650253837 2019-07-18 20:45:00    65025383700
#
#                     title  category_id  beer_brand_id  beer_serving_type_id  \
# 76        bbq chick sandw          2.0              0                     0
# 90   standard greek salad          2.0              0                     0
# 139            fish tacos          2.0              0                     0
# 178       chicken fingers          2.0              0                     0
# 179            fish tacos          2.0              0                     0
#
#      beer_volume  item_qty  sales_before_tax  sales_inc_tax  guest_count  \
# ...

# %%
# glasses, over medium,poached medium, spicy,.grain.rice, allergy,sauce, add,garlic.aioli
# birthday!!!!!!!!!!!,bucket of ice, grilled chicken, free togo, do not make, dressing on side, happy birthday,
# hot

# %%
# Extra, Add, cost>0, SAUCE, -NO , sauce, Side,SIDE????, s/o, +, n/c
def filter_titles(title):
    if "extra" in title:
        return False
    elif "add" in title:
        return False
    elif "sauce" in title:
        return False
    elif "no " in title:
        return False
    elif "no." in title:
        return False
    elif "-no " in title:
        return False
    elif "side " in title:
        return False
    elif "+" in title:
        return False
    elif "dip" in title:
        return False
    elif "blue cheese" in title:
        return False
    elif "bbq" in title:
        return False
    elif "n/c" in title:
        return False
    elif "s/o" in title:
        return False
    elif title == '' or title == 'garlic.aioli' or title == 'gluten' or title == 'hot n honey' or title == 'honey garlic' or title == 'kids.' or title == 'to go':
        return False
    else:
        return True

# %%
df_new = df_category2[df_category2['title'].map(filter_titles) == True]
df_new.shape
# Out:
# (132584, 19)

# %%
# x2 = df_new.groupby(["title", "sales_inc_tax"]).size().reset_index(name="num_orders")

# %%
# df_new.groupby(["title", "sales_inc_tax"]).size().reset_index(name="num_orders")

# %%
newst = df[~((df['category_id'] == 2) & (df['title'].map(filter_titles) == False))]
# print(newst.shape)
# print(df.shape)
# newst.loc[newst.category_id == 2].head(20)
# Out:
# (301358, 19)
# (320805, 19)
#         city  bar_id   order_id          order_time  order_item_id  \
# 90   Toronto    3379  650212816 2019-07-18 20:49:39    65021281601
# 139  Toronto   17125  649881063 2019-07-18 11:43:00    64988106300
# 178  Toronto    3379  650228446 2019-07-18 21:42:34    65022844604
# 179  Toronto   17125  650253837 2019-07-18 20:45:00    65025383700
# 197  Toronto   17125  649947226 2019-07-18 14:39:00    64994722600
# 251  Toronto    3379  650192951 2019-07-18 19:43:36    65019295102
# 255  Toronto    3379  650192951 2019-07-18 19:43:36    65019295101
# 343  Toronto   17125  649928857 2019-07-18 11:45:00    64992885701
# 429  Toronto   17125  650166732 2019-07-18 16:38:00    65016673202
# 431  Toronto   17125  650166732 2019-07-18 16:38:00    65016673206
# 432  Toronto   17125  650166732 2019-07-18 16:38:00    65016673205
# 433  Toronto   17125  650166732 2019-07-18 16:38:00    65016673204
# 435  Toronto   17125  650166732 2019-07-18 16:38:00    65016673203
# ...
