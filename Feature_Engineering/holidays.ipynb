# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
dates = pd.read_csv("../data/calendarific-holidays-2018-_all_.csv")

# %%
dates = dates[dates["Country"] == "Canada"].reset_index()

# %%
# Toronto is in Ontario
#all holidays are based on this page https://en.wikipedia.org/wiki/Public_holidays_in_Canada
# Out:
#    index        Date                      Name  Year  Month  Day Weekday  \
# 0    760  2018-01-01            New Year's Day  2018      1    1     Mon
# 1    761  2018-01-02  Day After New Year’s Day  2018      1    2     Tue
# 2    762  2018-01-06                  Epiphany  2018      1    6     Sat
# 3    763  2018-01-07    Orthodox Christmas Day  2018      1    7     Sun
# 4    764  2018-01-14         Orthodox New Year  2018      1   14     Sun
#
#                   Types  IsObserved Country Locations  States
# 0      National holiday         NaN  Canada       NaN     NaN
# 1         Local holiday         NaN  Canada        QC  Quebec
# 2  Observance,Christian         NaN  Canada       NaN     NaN
# 3              Orthodox         NaN  Canada       NaN     NaN
# 4              Orthodox         NaN  Canada       NaN     NaN

# %%
dates[dates["Name"].isin(["New Year's Day","Good Friday","Canada Day","Labour Day","Christmas Day"])]
# Out:
#     index        Date            Name  Year  Month  Day Weekday  \
# 0     760  2018-01-01  New Year's Day  2018      1    1     Mon
# 26    786  2018-03-30     Good Friday  2018      3   30     Fri
# 62    822  2018-07-01      Canada Day  2018      7    1     Sun
# 63    823  2018-07-01      Canada Day  2018      7    1     Sun
# 82    842  2018-09-03      Labour Day  2018      9    3     Mon
#
#                          Types  IsObserved Country Locations  \
# 0             National holiday         NaN  Canada       NaN
# 26  National holiday,Christian         NaN  Canada       NaN
# 62            National holiday         NaN  Canada    NS, NL
# 63            National holiday         NaN  Canada       NaN
# 82            National holiday         NaN  Canada       NaN
#
#                                    States
# 0                                     NaN
# 26                                    NaN
# 62  Nova Scotia,Newfoundland and Labrador
# ...

# %%
holidays = dates[dates["Types"] == "National holiday"]
holidays
# Out:
#      index        Date                      Name  Year  Month  Day Weekday  \
# 0      760  2018-01-01            New Year's Day  2018      1    1     Mon
# 31     791  2018-04-02             Easter Monday  2018      4    2     Mon
# 50     810  2018-05-21              Victoria Day  2018      5   21     Mon
# 62     822  2018-07-01                Canada Day  2018      7    1     Sun
# 63     823  2018-07-01                Canada Day  2018      7    1     Sun
# 65     825  2018-07-02       Canada Day observed  2018      7    2     Mon
# 72     832  2018-08-06      Civic/Provincial Day  2018      8    6     Mon
# 82     842  2018-09-03                Labour Day  2018      9    3     Mon
# 91     851  2018-10-08          Thanksgiving Day  2018     10    8     Mon
# 99     859  2018-11-11           Remembrance Day  2018     11   11     Sun
# 102    862  2018-11-12  Remembrance Day observed  2018     11   12     Mon
# ...

# %%
holidays = holidays.append(dates[dates["Name"].isin(["Family Day"])])
holidays
# Out:
#      index        Date                      Name  Year  Month  Day Weekday  \
# 0      760  2018-01-01            New Year's Day  2018      1    1     Mon
# 31     791  2018-04-02             Easter Monday  2018      4    2     Mon
# 50     810  2018-05-21              Victoria Day  2018      5   21     Mon
# 62     822  2018-07-01                Canada Day  2018      7    1     Sun
# 63     823  2018-07-01                Canada Day  2018      7    1     Sun
# 65     825  2018-07-02       Canada Day observed  2018      7    2     Mon
# 72     832  2018-08-06      Civic/Provincial Day  2018      8    6     Mon
# 82     842  2018-09-03                Labour Day  2018      9    3     Mon
# 91     851  2018-10-08          Thanksgiving Day  2018     10    8     Mon
# 99     859  2018-11-11           Remembrance Day  2018     11   11     Sun
# 102    862  2018-11-12  Remembrance Day observed  2018     11   12     Mon
# ...

# %%
# march break is not in the dates I found although it is in the wiki page. it is only for school though
dates[dates["Month"].isin([3])]
# Out:
#     index        Date                         Name  Year  Month  Day Weekday  \
# 18    778  2018-03-01                        Purim  2018      3    1     Thu
# 19    779  2018-03-01               St David's Day  2018      3    1     Thu
# 20    780  2018-03-11  Daylight Saving Time starts  2018      3   11     Sun
# 21    781  2018-03-12             Commonwealth Day  2018      3   12     Mon
# 22    782  2018-03-17            St. Patrick's Day  2018      3   17     Sat
# 23    783  2018-03-19            St. Patrick's Day  2018      3   19     Mon
# 24    784  2018-03-25                  Palm Sunday  2018      3   25     Sun
# 25    785  2018-03-29              Maundy Thursday  2018      3   29     Thu
# 26    786  2018-03-30                  Good Friday  2018      3   30     Fri
# 27    787  2018-03-31                Holy Saturday  2018      3   31     Sat
# 28    788  2018-03-31        First day of Passover  2018      3   31     Sat
#
# ...

# %%
holidays = holidays.drop(7) # drop duplicate row

# %%
holidays.reset_index()
# Out:
#     level_0  index        Date                      Name  Year  Month  Day  \
# 0         0    760  2018-01-01            New Year's Day  2018      1    1
# 1        31    791  2018-04-02             Easter Monday  2018      4    2
# 2        50    810  2018-05-21              Victoria Day  2018      5   21
# 3        62    822  2018-07-01                Canada Day  2018      7    1
# 4        63    823  2018-07-01                Canada Day  2018      7    1
# 5        65    825  2018-07-02       Canada Day observed  2018      7    2
# 6        72    832  2018-08-06      Civic/Provincial Day  2018      8    6
# 7        82    842  2018-09-03                Labour Day  2018      9    3
# 8        91    851  2018-10-08          Thanksgiving Day  2018     10    8
# 9        99    859  2018-11-11           Remembrance Day  2018     11   11
# 10      102    862  2018-11-12  Remembrance Day observed  2018     11   12
# ...

# %%
# this is the list of holidays in Toronto state. 
# still needs to update them to 2019

# %%
holidays
# Out:
#      index        Date                      Name  Year  Month  Day Weekday  \
# 0      760  2018-01-01            New Year's Day  2018      1    1     Mon
# 31     791  2018-04-02             Easter Monday  2018      4    2     Mon
# 50     810  2018-05-21              Victoria Day  2018      5   21     Mon
# 62     822  2018-07-01                Canada Day  2018      7    1     Sun
# 63     823  2018-07-01                Canada Day  2018      7    1     Sun
# 65     825  2018-07-02       Canada Day observed  2018      7    2     Mon
# 72     832  2018-08-06      Civic/Provincial Day  2018      8    6     Mon
# 82     842  2018-09-03                Labour Day  2018      9    3     Mon
# 91     851  2018-10-08          Thanksgiving Day  2018     10    8     Mon
# 99     859  2018-11-11           Remembrance Day  2018     11   11     Sun
# 102    862  2018-11-12  Remembrance Day observed  2018     11   12     Mon
# ...
